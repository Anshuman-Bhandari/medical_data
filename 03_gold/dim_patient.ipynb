# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medical_project.gold;

# %%
from pyspark.sql.functions import col

dim_patient = spark.table("medical_project.silver.patients") \
    .select(
        col("id").alias("patient_id"),
        "gender",
        "race",
        "ethnicity"
    )

display(dim_patient)

# %%
dim_patient.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("medical_project.gold.dim_patient")

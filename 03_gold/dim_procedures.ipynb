# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medical_project.gold;

# %%
from pyspark.sql.functions import col

dim_procedure = spark.table("medical_project.silver.procedures") \
    .select(
        col("code").alias("procedure_code"),
        col("description")
    ) \
    .dropDuplicates(["procedure_code"])

display(dim_procedure)

# %%
dim_procedure.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("medical_project.gold.dim_procedure")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medical_project.gold;

# %%
dim_payer = spark.table("medical_project.silver.payers") \
    .select(
        col("id").alias("payer_id"),
        col("name").alias("payer_name")
    )
    
display(dim_payer)

# %%
dim_payer.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("medical_project.gold.dim_payer")
